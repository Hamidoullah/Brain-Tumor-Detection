# %%
# for unzip files
# import zipfile
# z = zipfile.ZipFile("archive.zip")
# z.extractall()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Définir les chemins de chaque sous-dossier
pathTumor = "/content/drive/MyDrive/Colab Notebooks/FSM-TP/Projets/Brain tumor classification/Dataset/tumor"
pathHealthy = "/content/drive/MyDrive/Colab Notebooks/FSM-TP/Projets/Brain tumor classification/Dataset/healthy"

# %%
import os                        # To work with operation system commands
import cv2                       # To process images
import random                    # to generate random choices
import warnings                  # To avoid python warnings
import numpy as np               # To work with arrays
import pandas as pd              # To work with DataFrames
import seaborn as sns            # To visualizations
from tqdm import tqdm            # To represent progress bars
import matplotlib.pyplot as plt  # To visualizations

# %%
# ignore python warnings
warnings.filterwarnings('ignore')

# add style to plots
plt.style.use('fivethirtyeight')
sns.set_style('darkgrid')

# %%
Nb_Tumor = len(os.listdir(pathTumor))
Nb_Healthy = len(os.listdir(pathHealthy))

print(f' Number of Tumor Images : {Nb_Tumor}')
print(f' Number of Healthy Images : {Nb_Healthy}')
print('_'*40)
print(f' Number of All Images : {Nb_Tumor + Nb_Healthy} ')
# Out:
#  Number of Tumor Images : 392
#  Number of Healthy Images : 408
# ________________________________________
#  Number of All Images : 800

# %%
labels = ['Tumor', 'Healthy']
sizes = [Nb_Tumor / (Nb_Tumor + Nb_Healthy), Nb_Healthy / (Nb_Tumor + Nb_Healthy)]
colors = ['#FF6F61', '#6B8E23']  # Optional colors for clarity
explode = (0.1, 0)  # "explode" the Tumor slice slightly for emphasis

# Create the pie chart
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140, explode=explode, shadow=True)
ax.set_title("Distribution of Tumor vs. Healthy Cells")

# Display the chart
plt.show()

# %%
# Prepare the data
listx = ["Tumor"] * Nb_Tumor + ["Healthy"] * Nb_Healthy

# Plot
plt.figure(figsize=(8, 6))
sns.countplot(x=listx, palette="pastel")
plt.title("Distribution of Tumor and Healthy Cases")
plt.xlabel("Diagnosis")
plt.ylabel("Count")

# Show plot
plt.show()

# %%
def Image_Size(train_images) :
    '''
    Read images and save image-sizes in a set
    '''
    img_sizes = set()

    # Loop over train images and read them
    for img_name in tqdm(os.listdir(train_images)) :
        img_path = os.path.join(train_images, img_name)
        img = cv2.imread(img_path)
        h, w, c = img.shape
        img_sizes.add((h, w))

    return img_sizes

# %%
img_sizes_Unique_Tumor = Image_Size(pathTumor)
img_sizes_Unique_Healthy = Image_Size(pathHealthy)

print("\n \t For Tumor images : ")
if len(img_sizes_Unique_Tumor) == 1 :
    print(f'All the images have size of {img_sizes_Unique_Tumor} ')
else :
    print(f'There are {len(img_sizes_Unique_Tumor)} different image sizes ! ')

print('_'*40)
print("\n \t For Healtht images : ")
if len(img_sizes_Unique_Healthy) == 1 :
    print(f'All the images have size of {img_sizes_Unique_Healthy} ')
else :
    print(f'There are {len(img_sizes_Unique_Healthy)} different image sizes ! ')
# Out:
# 100%|██████████| 392/392 [00:07<00:00, 52.74it/s]
# 100%|██████████| 408/408 [00:07<00:00, 52.43it/s]
#  	 For Tumor images :
# There are 55 different image sizes !
# ________________________________________
#
#  	 For Healtht images :
# There are 116 different image sizes !

# %%
from sklearn.model_selection import train_test_split


# Créer les listes de chemins d'images et de labels
image_paths = []
labels = []

# Charger les images de "Tumor" avec le label 1
for filename in os.listdir(pathTumor):
    image_paths.append(os.path.join(pathTumor, filename))
    labels.append("Tumor")  # Label pour 'Tumor'

# Charger les images de "Healthy" avec le label 0
for filename in os.listdir(pathHealthy):
    image_paths.append(os.path.join(pathHealthy, filename))
    labels.append("Healthy")  # Label pour 'Healthy'

# Convertir en tableaux numpy pour faciliter la division
image_paths = np.array(image_paths)
labels = np.array(labels)

# %%
plt.figure(figsize=(20, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    img = plt.imread(image_paths[i])
    plt.imshow(img, cmap="gray")
    plt.axis("off")
    # Utiliser une expression conditionnelle pour le titre
    plt.title(labels[i])
plt.tight_layout()
plt.show()  # Assurez-vous d'afficher le graphique

# %%
# Diviser en train et temp (80% train, 20% temp)
image_paths_train, image_paths_temp, labels_train, labels_temp = train_test_split(
    image_paths, labels, test_size=0.2, random_state=42, stratify=labels
)

# Diviser temp en validation et test (50% validation, 50% test)
image_paths_val, image_paths_test, labels_val, labels_test = train_test_split(
    image_paths_temp, labels_temp, test_size=0.5, random_state=42, stratify=labels_temp
)

# Résumé des tailles
print("Train size:", len(image_paths_train))
print("Validation size:", len(image_paths_val))
print("Test size:", len(image_paths_test))
# Out:
# Train size: 640
# Validation size: 80
# Test size: 80

# %%
plt.figure(figsize=(20, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    img = plt.imread(image_paths_train[i])
    plt.imshow(img, cmap="gray")
    plt.axis("off")
    # Utiliser une expression conditionnelle pour le titre
    plt.title(labels_train[i])
plt.tight_layout()
plt.show()  # Assurez-vous d'afficher le graphique

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.utils import to_categorical


# Convertir les chemins et labels en DataFrames
train_df = pd.DataFrame({'filename': image_paths_train, 'class': labels_train})
val_df = pd.DataFrame({'filename': image_paths_val, 'class': labels_val})
test_df = pd.DataFrame({'filename': image_paths_test, 'class': labels_test})


# Initialiser ImageDataGenerator
datagen = ImageDataGenerator(rescale=1.0/255)

# Générateurs pour train, validation et test
train_gen = datagen.flow_from_dataframe(train_df, x_col='filename', y_col='class',
                                        target_size=(224, 224), batch_size=32,
                                        class_mode='categorical', shuffle=True, seed=42,color_mode='rgb')
val_gen = datagen.flow_from_dataframe(val_df, x_col='filename', y_col='class',
                                      target_size=(224, 224), batch_size=32,
                                      class_mode='categorical', shuffle=True, seed=42,color_mode='rgb')
test_gen = datagen.flow_from_dataframe(test_df, x_col='filename', y_col='class',
                                       target_size=(224, 224), batch_size=32,
                                       class_mode='categorical', shuffle=False, seed=42,color_mode='rgb')

# Les labels sont déjà intégrés en fonction de la structure des dossiers
print(train_gen.class_indices)  # Affiche : {'Healthy': 0, 'Tumor': 1}
# Out:
# Found 640 validated image filenames belonging to 2 classes.
# Found 80 validated image filenames belonging to 2 classes.
# Found 80 validated image filenames belonging to 2 classes.
# {'Healthy': 0, 'Tumor': 1}

# %%
class_labels = train_gen.class_indices
print(class_labels)
# Out:
# {'Healthy': 0, 'Tumor': 1}

# %%
class_name = {value:key for (key, value) in class_labels.items()}
print(class_name)
# Out:
# {0: 'Healthy', 1: 'Tumor'}

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input, Dense, Flatten, Conv2D, Dropout, BatchNormalization
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.optimizers import SGD, RMSprop, Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
# Charger le modèle de base VGG19 avec des poids d'ImageNet
base_model = VGG19(input_shape=(224, 224, 3), include_top=False, weights="imagenet")

# Geler les couches de VGG19 pour conserver les caractéristiques pré-entraînées
for layer in base_model.layers:
    layer.trainable = False

# Ajouter des couches fully-connected pour la classification
x = base_model.output
x = Flatten()(x)
x = Dense(1024, activation='relu')(x)        # Couches denses avec réduction de la taille
x = BatchNormalization()(x)                  # Normalisation pour stabiliser l'entraînement
x = Dropout(0.4)(x)

x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)

# Couche de sortie
output = Dense(2, activation="softmax")(x)

# Définir le modèle final
model_01 = Model(inputs=base_model.inputs, outputs=output)
model_01.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 112, 112, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 112, 112, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 56, 56, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv4 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 28, 28, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv4 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv4 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1024)                │      25,691,136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 1024)                │           4,096 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 2)                   │           1,026 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 46,247,490 (176.42 MB)
#  Trainable params: 26,220,034 (100.02 MB)
#  Non-trainable params: 20,027,456 (76.40 MB)

# %%
# Définir le chemin avec un nom de fichier qui inclut les meilleures performances pour un suivi plus clair
filepath = "best_model_val_loss_{val_loss:.4f}.keras"

# Callbacks
es = EarlyStopping(monitor="val_loss", mode="min", patience=6, verbose=1, restore_best_weights=True)  # Augmentation de la patience et restauration des meilleurs poids
cp = ModelCheckpoint(filepath, monitor="val_loss", mode="min", save_best_only=True, save_weights_only=False, verbose=1)
lrr = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=4, min_lr=1e-5, verbose=1)  # Facteur réduit et moniteur basé sur val_loss pour la stabilité de l'apprentissage

# Optimiseur avec un taux d'apprentissage ajustable et un momentum élevé
sgd = SGD(learning_rate=1e-4, momentum=0.9, nesterov=True)  # Augmentation du momentum pour une convergence plus rapide

# Compilation du modèle
model_01.compile(loss="categorical_crossentropy", optimizer=sgd, metrics=['accuracy'])

# %%
# Entraînement avec callbacks et paramètres d’entraînement améliorés
history_01 = model_01.fit(
    train_gen,
    steps_per_epoch=80,
    epochs=50,  # Augmentation des époques pour un meilleur entraînement
    callbacks=[es, cp, lrr],
    validation_data=val_gen,
    validation_steps=40
)
# Out:
# Epoch 1/50
# 20/80 ━━━━━━━━━━━━━━━━━━━━ 13s 221ms/step - accuracy: 0.7448 - loss: 0.6297
# Epoch 1: val_loss improved from inf to 0.55262, saving model to best_model_val_loss_0.5526.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 37s 214ms/step - accuracy: 0.7967 - loss: 0.5257 - val_accuracy: 0.5625 - val_loss: 0.5526 - learning_rate: 1.0000e-04
# Epoch 2/50
# 20/80 ━━━━━━━━━━━━━━━━━━━━ 11s 185ms/step - accuracy: 0.9274 - loss: 0.2414
# Epoch 2: val_loss did not improve from 0.55262
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - accuracy: 0.9256 - loss: 0.2389 - val_accuracy: 0.6000 - val_loss: 0.5581 - learning_rate: 1.0000e-04
# Epoch 3/50
# 20/80 ━━━━━━━━━━━━━━━━━━━━ 9s 151ms/step - accuracy: 0.9464 - loss: 0.1459
# Epoch 3: val_loss improved from 0.55262 to 0.52367, saving model to best_model_val_loss_0.5237.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.9374 - loss: 0.1643 - val_accuracy: 0.6625 - val_loss: 0.5237 - learning_rate: 1.0000e-04
# Epoch 4/50
# 20/80 ━━━━━━━━━━━━━━━━━━━━ 11s 190ms/step - accuracy: 0.9606 - loss: 0.1027
# Epoch 4: val_loss improved from 0.52367 to 0.48162, saving model to best_model_val_loss_0.4816.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 102ms/step - accuracy: 0.9515 - loss: 0.1208 - val_accuracy: 0.7250 - val_loss: 0.4816 - learning_rate: 1.0000e-04
# Epoch 5/50
# 20/80 ━━━━━━━━━━━━━━━━━━━━ 9s 153ms/step - accuracy: 0.9405 - loss: 0.1470
# Epoch 5: val_loss improved from 0.48162 to 0.41251, saving model to best_model_val_loss_0.4125.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9476 - loss: 0.1338 - val_accuracy: 0.8250 - val_loss: 0.4125 - learning_rate: 1.0000e-04
# Epoch 6/50
# 20/80 ━━━━━━━━━━━━━━━━━━━━ 9s 154ms/step - accuracy: 0.9592 - loss: 0.1200
# Epoch 6: val_loss improved from 0.41251 to 0.30054, saving model to best_model_val_loss_0.3005.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 127ms/step - accuracy: 0.9664 - loss: 0.1158 - val_accuracy: 0.9125 - val_loss: 0.3005 - learning_rate: 1.0000e-04
# Epoch 7/50
# 20/80 ━━━━━━━━━━━━━━━━━━━━ 9s 152ms/step - accuracy: 0.9594 - loss: 0.1096
# Epoch 7: val_loss improved from 0.30054 to 0.23494, saving model to best_model_val_loss_0.2349.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 16s 78ms/step - accuracy: 0.9617 - loss: 0.1060 - val_accuracy: 0.9125 - val_loss: 0.2349 - learning_rate: 1.0000e-04
# Epoch 8/50
# 20/80 ━━━━━━━━━━━━━━━━━━━━ 9s 151ms/step - accuracy: 0.9747 - loss: 0.0644
# Epoch 8: val_loss did not improve from 0.23494
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - accuracy: 0.9726 - loss: 0.0694 - val_accuracy: 0.9250 - val_loss: 0.2535 - learning_rate: 1.0000e-04
# Epoch 9/50
# 20/80 ━━━━━━━━━━━━━━━━━━━━ 9s 153ms/step - accuracy: 0.9724 - loss: 0.0624
# Epoch 9: val_loss improved from 0.23494 to 0.22745, saving model to best_model_val_loss_0.2274.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 125ms/step - accuracy: 0.9744 - loss: 0.0646 - val_accuracy: 0.9250 - val_loss: 0.2274 - learning_rate: 1.0000e-04
# Epoch 10/50
# 20/80 ━━━━━━━━━━━━━━━━━━━━ 9s 153ms/step - accuracy: 0.9777 - loss: 0.0656
# Epoch 10: val_loss improved from 0.22745 to 0.20041, saving model to best_model_val_loss_0.2004.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 131ms/step - accuracy: 0.9780 - loss: 0.0706 - val_accuracy: 0.9250 - val_loss: 0.2004 - learning_rate: 1.0000e-04
# Epoch 11/50
# 20/80 ━━━━━━━━━━━━━━━━━━━━ 12s 208ms/step - accuracy: 0.9686 - loss: 0.0559
# Epoch 11: val_loss improved from 0.20041 to 0.16358, saving model to best_model_val_loss_0.1636.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 17s 89ms/step - accuracy: 0.9699 - loss: 0.0602 - val_accuracy: 0.9375 - val_loss: 0.1636 - learning_rate: 1.0000e-04
# Epoch 12/50
# 20/80 ━━━━━━━━━━━━━━━━━━━━ 10s 182ms/step - accuracy: 0.9888 - loss: 0.0492
# Epoch 12: val_loss improved from 0.16358 to 0.14353, saving model to best_model_val_loss_0.1435.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 14s 137ms/step - accuracy: 0.9855 - loss: 0.0531 - val_accuracy: 0.9375 - val_loss: 0.1435 - learning_rate: 1.0000e-04
# Epoch 13/50
# 20/80 ━━━━━━━━━━━━━━━━━━━━ 9s 166ms/step - accuracy: 0.9876 - loss: 0.0535
# Epoch 13: val_loss improved from 0.14353 to 0.11267, saving model to best_model_val_loss_0.1127.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 9s 90ms/step - accuracy: 0.9828 - loss: 0.0569 - val_accuracy: 0.9250 - val_loss: 0.1127 - learning_rate: 1.0000e-04
# Epoch 14/50
# 20/80 ━━━━━━━━━━━━━━━━━━━━ 9s 156ms/step - accuracy: 0.9792 - loss: 0.0604
# Epoch 14: val_loss improved from 0.11267 to 0.10282, saving model to best_model_val_loss_0.1028.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.9784 - loss: 0.0579 - val_accuracy: 0.9625 - val_loss: 0.1028 - learning_rate: 1.0000e-04
# Epoch 15/50
# 20/80 ━━━━━━━━━━━━━━━━━━━━ 9s 161ms/step - accuracy: 0.9886 - loss: 0.0356
# Epoch 15: val_loss improved from 0.10282 to 0.09858, saving model to best_model_val_loss_0.0986.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - accuracy: 0.9854 - loss: 0.0427 - val_accuracy: 0.9625 - val_loss: 0.0986 - learning_rate: 1.0000e-04
# Epoch 16/50
# 20/80 ━━━━━━━━━━━━━━━━━━━━ 9s 156ms/step - accuracy: 0.9757 - loss: 0.0485
# Epoch 16: val_loss improved from 0.09858 to 0.09493, saving model to best_model_val_loss_0.0949.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - accuracy: 0.9787 - loss: 0.0477 - val_accuracy: 0.9625 - val_loss: 0.0949 - learning_rate: 1.0000e-04
# Epoch 17/50
# 20/80 ━━━━━━━━━━━━━━━━━━━━ 9s 157ms/step - accuracy: 0.9917 - loss: 0.0277
# Epoch 17: val_loss improved from 0.09493 to 0.09375, saving model to best_model_val_loss_0.0938.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.9909 - loss: 0.0288 - val_accuracy: 0.9500 - val_loss: 0.0938 - learning_rate: 1.0000e-04
# Epoch 18/50
# 20/80 ━━━━━━━━━━━━━━━━━━━━ 9s 160ms/step - accuracy: 0.9856 - loss: 0.0359
# Epoch 18: val_loss improved from 0.09375 to 0.09177, saving model to best_model_val_loss_0.0918.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 97ms/step - accuracy: 0.9870 - loss: 0.0351 - val_accuracy: 0.9500 - val_loss: 0.0918 - learning_rate: 1.0000e-04
# Epoch 19/50
# 20/80 ━━━━━━━━━━━━━━━━━━━━ 10s 167ms/step - accuracy: 0.9851 - loss: 0.0482
# Epoch 19: val_loss did not improve from 0.09177
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9834 - loss: 0.0500 - val_accuracy: 0.9500 - val_loss: 0.0922 - learning_rate: 1.0000e-04
# Epoch 20/50
# 20/80 ━━━━━━━━━━━━━━━━━━━━ 9s 156ms/step - accuracy: 0.9853 - loss: 0.0388
# Epoch 20: val_loss did not improve from 0.09177
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - accuracy: 0.9881 - loss: 0.0364 - val_accuracy: 0.9500 - val_loss: 0.0919 - learning_rate: 1.0000e-04
# Epoch 21/50
# 20/80 ━━━━━━━━━━━━━━━━━━━━ 9s 157ms/step - accuracy: 0.9865 - loss: 0.0453
# Epoch 21: val_loss did not improve from 0.09177
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.9884 - loss: 0.0411 - val_accuracy: 0.9500 - val_loss: 0.0954 - learning_rate: 1.0000e-04
# Epoch 22/50
# 20/80 ━━━━━━━━━━━━━━━━━━━━ 11s 185ms/step - accuracy: 0.9968 - loss: 0.0242
# Epoch 22: val_loss did not improve from 0.09177
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - accuracy: 0.9945 - loss: 0.0264 - val_accuracy: 0.9375 - val_loss: 0.1019 - learning_rate: 1.0000e-04
# Epoch 23/50
# 20/80 ━━━━━━━━━━━━━━━━━━━━ 9s 154ms/step - accuracy: 0.9899 - loss: 0.0285
# Epoch 23: val_loss did not improve from 0.09177
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - accuracy: 0.9822 - loss: 0.0396 - val_accuracy: 0.9375 - val_loss: 0.1000 - learning_rate: 5.0000e-05
# Epoch 24/50
# 20/80 ━━━━━━━━━━━━━━━━━━━━ 11s 193ms/step - accuracy: 0.9854 - loss: 0.0513
# Epoch 24: val_loss did not improve from 0.09177
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - accuracy: 0.9881 - loss: 0.0404 - val_accuracy: 0.9375 - val_loss: 0.1003 - learning_rate: 5.0000e-05
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 18.

# %%
if not os.path.isdir('model_weights/'):
    os.mkdir("model_weights/")
model_01.save(filepath="model_weights/vgg19_model_01.keras", overwrite=True)

# %%
model_01.load_weights("model_weights/vgg19_model_01.keras")
vgg_val_eval_01 = model_01.evaluate(val_gen)
vgg_test_eval_01 = model_01.evaluate(test_gen)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - accuracy: 0.9555 - loss: 0.0828
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - accuracy: 0.9820 - loss: 0.0424

# %%
print(f"Validation Loss {vgg_val_eval_01[0]}")
print(f"Validation Accuracy {vgg_val_eval_01[1]}")
print(f"Test Loss {vgg_test_eval_01[0]}")
print(f"Test Accuracy {vgg_test_eval_01[1]}")
# Out:
# Validation Loss 0.09176523983478546
# Validation Accuracy 0.949999988079071
# Test Loss 0.03273693472146988
# Test Accuracy 0.987500011920929

# %%
from PIL import Image

def get_className(classNo):
    """Retourne la classe en fonction du numéro."""
    if classNo == 0:
        return "Healthy"
    elif classNo == 1:
        return "Tumor"
    else:
        return "Unknown"

def getResult(img_path):
    """Prépare l'image et renvoie la prédiction de la classe."""
    # Charger l'image avec OpenCV
    image = cv2.imread(img_path)
    if image is None:
        raise ValueError(f"L'image n'a pas pu être chargée depuis le chemin : {img_path}")

    # Convertir en RGB et redimensionner pour le modèle
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = Image.fromarray(image)
    image = image.resize((224, 224))

    # Convertir en array et ajouter une dimension pour le batch
    input_img = np.expand_dims(np.array(image) / 255.0, axis=0)

    # Prédire la classe
    result = model_01.predict(input_img)
    class_index = np.argmax(result, axis=1)[0]
    return class_index

# %%
x = 0
for i in range(80):
  if(get_className(getResult(image_paths[i])) == labels_test[i]):
    x = x + 1
print(x)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 587ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 79

# %%
print(get_className(getResult(image_paths_test[5])))
print(labels_test[5])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Healthy
# Healthy

# %%
for i in range(80):
  print(get_className(getResult(image_paths_test[i])))
  print(labels_test[i])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Tumor
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Tumor
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Tumor
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Tumor
# Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Healthy
# Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Healthy
# Healthy

# %%
from google.colab import files

# Spécifiez le chemin de votre fichier
files.download('/content/model_weights/vgg19_model_01.keras')
